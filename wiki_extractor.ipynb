# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import requests 
import pandas as pd

# %%
keyword = input()
num_urls = int(input())
result = requests.get("https://en.wikipedia.org/wiki/" + keyword)
source = result.content
# Out:
# salman khan
# 5

# %%
driver = webdriver.Chrome()
soup = bs(source, 'html.parser')
links = soup.find_all("a")
print(links)
# Out:
# [<a id="top"></a>, <a href="/wiki/Wikipedia:Protection_policy#semi" title="This article is semi-protected."><img alt="Page semi-protected" data-file-height="512" data-file-width="512" decoding="async" height="20" src="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/30px-Semi-protection-shackle.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/40px-Semi-protection-shackle.svg.png 2x" width="20"/></a>, <a class="mw-redirect" href="/w/index.php?title=Salman_khan&amp;redirect=no" title="Salman khan">Salman khan</a>, <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>, <a class="mw-jump-link" href="#searchInput">Jump to search</a>, <a class="mw-disambig" href="/wiki/Salman_Khan_(disambiguation)" title="Salman Khan (disambiguation)">Salman Khan (disambiguation)</a>, <a class="image" href="/wiki/File:Salman_Khan_at_Renault_Star_Guild_Awards.jpg"><img alt="Salman Khan" data-file-height="387" data-file-width="283" decoding="async" height="301" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/86/Salman_Khan_at_Renault_Star_Guild_Awards.jpg/220px-Salman_Khan_at_Renault_Star_Guild_Awards.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/8/86/Salman_Khan_at_Renault_Star_Guild_Awards.jpg 1.5x" width="220"/></a>, <a class="mw-redirect" href="/wiki/Star_Guild_Awards" title="Star Guild Awards">Star Guild Awards</a>, <a href="#cite_note-1">[1]</a>, <a class="mw-redirect" href="/wiki/Indore,_Madhya_Pradesh" title="Indore, Madhya Pradesh">Indore, Madhya Pradesh</a>, <a href="/wiki/Salman_Khan_filmography" title="Salman Khan filmography">Full list</a>, <a href="/wiki/Sohail_Khan" title="Sohail Khan">Sohail Khan</a>, <a href="/wiki/Arbaaz_Khan" title="Arbaaz Khan">Arbaaz Khan</a>, <a href="/wiki/Alvira_Khan_Agnihotri" title="Alvira Khan Agnihotri">Alvira Khan Agnihotri</a>, <a href="/wiki/Helen_(actress)" title="Helen (actress)">Helen</a>, <a href="/wiki/Salim_Khan_family" title="Salim Khan family">Salim Khan family</a>, <a href="/wiki/List_of_awards_and_nominations_received_by_Salman_Khan" title="List of awards and nominations received by Salman Khan">Full list</a>, <a class="image" href="/wiki/File:Salman_Khan_signature.svg"><img alt="Salman Khan signature.svg" data-file-height="258" data-file-width="400" decoding="async" height="97" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d6/Salman_Khan_signature.svg/150px-Salman_Khan_signature.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d6/Salman_Khan_signature.svg/225px-Salman_Khan_signature.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/d6/Salman_Khan_signature.svg/300px-Salman_Khan_signature.svg.png 2x" width="150"/></a>, <a href="/wiki/Help:IPA/Hindi_and_Urdu" title="Help:IPA/Hindi and Urdu">[səlˈmɑːn xɑːn]</a>, <a href="#cite_note-2">[2]</a>, <a href="/wiki/Hindi" title="Hindi">Hindi</a>, <a href="/wiki/List_of_awards_and_nominations_received_by_Salman_Khan" title="List of awards and nominations received by Salman Khan">numerous awards</a>, <a href="/wiki/National_Film_Awards" title="National Film Awards">National Film Awards</a>, <a href="/wiki/Filmfare_Awards" title="Filmfare Awards">Filmfare Awards</a>, <a href="#cite_note-3">[3]</a>, <a href="/wiki/Cinema_of_India" title="Cinema of India">Indian cinema</a>, <a href="#cite_note-4">[4]</a>, <a href="#cite_note-5">[5]</a>, <a href="/wiki/Forbes" title="Forbes">Forbes</a>, <a href="/wiki/Amitabh_Bachchan" title="Amitabh Bachchan">Amitabh Bachchan</a>, <a href="#cite_note-6">[6]</a>, <a href="#cite_note-auto1-7">[7]</a>, <a href="#cite_note-Rich-8">[8]</a>, <a href="#cite_note-9">[9]</a>, <a href="/wiki/Bigg_Boss_(Hindi_TV_series)" title="Bigg Boss (Hindi TV series)">Bigg Boss</a>, <a href="#cite_note-10">[10]</a>, <a href="/wiki/Salim_Khan" title="Salim Khan">Salim Khan</a>, <a href="/wiki/Biwi_Ho_To_A ...
# You can view its source [e]"><span>View source</span></a>, <a accesskey="h" href="/w/index.php?title=Salman_Khan&amp;action=history" title="Past revisions of this page [h]"><span>View history</span></a>, <a class="mw-wiki-logo" href="/wiki/Main_Page" title="Visit the main page"></a>, <a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]"><span>Main page</span></a>, <a href="/wiki/Wikipedia:Contents" title="Guides to browsing Wikipedia"><span>Contents</span></a>, <a href="/wiki/Portal:Current_events" title="Articles related to current events"><span>Current events</span></a>, <a accesskey="x" href="/wiki/Special:Random" title="Visit a randomly selected article [x]"><span>Random article</span></a>, <a href="/wiki/Wikipedia:About" title="Learn about Wikipedia and how it works"><span>About Wikipedia</span></a>, <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia"><span>Contact us</span></a>, <a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us by donating to the Wikimedia Foundation"><span>Donate</span></a>, <a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia"><span>Help</span></a>, <a href="/wiki/Help:Introduction" title="Learn how to edit Wikipedia"><span>Learn to edit</span></a>, <a href="/wiki/Wikipedia:Community_portal" title="The hub for editors"><span>Community portal</span></a>, <a accesskey="r" href="/wiki/Special:RecentChanges" title="A list of recent changes to Wikipedia [r]"><span>Recent changes</span></a>, <a href="/wiki/Wikipedia:File_Upload_Wizard" title="Add images or other media for use on Wikipedia"><span>Upload file</span></a>, <a accesskey="j" href="/wiki/Special:WhatLinksHere/Salman_Khan" title="List of all English Wikipedia pages containing links to this page [j]"><span>What links here</span></a>, <a accesskey="k" href="/wiki/Special:RecentChangesLinked/Salman_Khan" rel="nofollow" title="Recent changes in pages linked from this page [k]"><span>Related changes</span></a>, <a accesskey="u" href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]"><span>Upload file</span></a>, <a accesskey="q" href="/wiki/Special:SpecialPages" title="A list of all special pages [q]"><span>Special pages</span></a>, <a href="/w/index.php?title=Salman_Khan&amp;oldid=1068680669" title="Permanent link to this revision of this page"><span>Permanent link</span></a>, <a href="/w/index.php?title=Salman_Khan&amp;action=info" title="More information about this page"><span>Page information</span></a>, <a href="/w/index.php?title=Special:CiteThisPage&amp;page=Salman_Khan&amp;id=1068680669&amp;wpFormIdentifier=titleform" title="Information on how to cite this page"><span>Cite this page</span></a>, <a accesskey="g" href="https://www.wikidata.org/wiki/Special:EntityPage/Q9543" title="Structured data on this page hosted by Wikidata [g]"><span>Wikidata item</span></a>, <a href="/w/index.php?title=Special:DownloadAsPdf&amp;page=Salman_Khan&amp;action=show-download-screen" title="Download this page as a PDF file"><span>Download as PDF</span></a>, <a accesskey="p" href="/w/index.php?title=Salman_Khan&amp;printable=yes" title="Printable version of this page [p]"><span>Printable version</span></a>, <a href="https://commons.wikimedia.org/wiki/Salman_Khan" hreflang="en"><span>Wikimedia Commons</span></a>, <a href="https://en.wikiquote.org/wiki/Salman_Khan" hreflang="en"><span>Wikiquote</span></a>, <a class="interlanguage-link-target" href="https://af.wikipedia.org/wiki/Salman_Khan" hreflang="af" lang="af" title="Salman Khan – Afrikaans"><span>Afrikaans</span></a>, <a class="interlanguage-link-target" href="https://am.wikipedia.org/wiki/%E1%88%B3%E1%88%8D%E1%88%9B%E1%8A%95_%E1%8A%BB%E1%8A%95" hreflang="am" lang="am" title="ሳልማን ኻን – Amharic"><span>አማርኛ</span></a>, <a class="interlanguage-link-target" href="https://ar.wikipedia.org/wiki/%D8 ...

# %%
urls = []
for link in links:
    
    url = link.get('href')
    if url and "/wiki/" in url:
        urls.append("https://en.wikipedia.org" + url)
        urls.append(url)
    
#print(urls)
#dataframe.to_csv('data.csv', index = False)

# %%
for url in urls[1:num_urls]:
    if url and "https://" in url:
        texts = driver.find_element("body")
        print(texts.text)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Input In [72], in <module>
#       1 for url in urls[1:num_urls]:
#       2     if url and "https://" in url:
#       3         #driver.get(url)
#       4         #para = soup.findAll("p")
#       5         #print(para)
#       6         #para = soup.find("p").text
#       7         #print(url)
# ----> 8         texts = driver.find_element("body")
#       9         print(texts.text)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:1244, in WebDriver.find_element(self, by, value)
#    1241     by = By.CSS_SELECTOR
#    1242     value = '[name="%s"]' % value
# -> 1244 return self.execute(Command.FIND_ELEMENT, {
#    1245     'using': by,
#    1246     'value': value})['value']
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:424, in WebDriver.execute(self, driver_command, params)
#     422 response = self.command_executor.execute(driver_command, params)
#     423 if response:
# --> 424     self.error_handler.check_response(response)
#     425     response['value'] = self._unwrap_value(
#     426         response.get('value', None))
#     427     return response
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=98.0.4758.82)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00877AC3+2587331]
# 	Ordinal0 [0x0080ADD1+2141649]
# 	Ordinal0 [0x00703A80+1063552]
# 	Ordinal0 [0x006F8222+1016354]
# 	Ordinal0 [0x006F8A58+1018456]
# 	Ordinal0 [0x006FA292+1024658]
# 	Ordinal0 [0x006F3F79+999289]
# 	Ordinal0 [0x00704EF0+1068784]
# 	Ordinal0 [0x007581D2+1409490]
# 	Ordinal0 [0x007484A6+1344678]
# 	Ordinal0 [0x007253F6+1201142]
# 	Ordinal0 [0x007262E6+1204966]
# 	GetHandleVerifier [0x00A1DF22+1680738]
# 	GetHandleVerifier [0x00AD0DBC+2413564]
# 	GetHandleVerifier [0x0090D151+563089]
# 	GetHandleVerifier [0x0090BF13+558419]
# 	Ordinal0 [0x0081081E+2164766]
# 	Ordinal0 [0x00815508+2184456]
# 	Ordinal0 [0x00815650+2184784]
# 	Ordinal0 [0x0081F5BC+2225596]
# 	BaseThreadInitThunk [0x76C7FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BF7A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BF7A6E+238]
